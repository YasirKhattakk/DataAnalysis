# %% [markdown]
# <a href="https://colab.research.google.com/github/YasirKhattakk/DataAnalysis/blob/main/Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#""""#

# %% [markdown]
# # **Bike store sales**  ![image.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Importing essentials**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### *Loading dataset...*

# %%
# !head sample_data/sales_data.csv
# Out:
# Date,Day,Month,Year,Customer_Age,Age_Group,Customer_Gender,Country,State,Product_Category,Sub_Category,Product,Order_Quantity,Unit_Cost,Unit_Price,Profit,Cost,Revenue
# 2013-11-26,26,November,2013,19,Youth (<25),M,Canada,British Columbia,Accessories,Bike Racks,Hitch Rack - 4-Bike,8,45,120,590,360,950
# 2015-11-26,26,November,2015,19,Youth (<25),M,Canada,British Columbia,Accessories,Bike Racks,Hitch Rack - 4-Bike,8,45,120,590,360,950
# 2014-03-23,23,March,2014,49,Adults (35-64),M,Australia,New South Wales,Accessories,Bike Racks,Hitch Rack - 4-Bike,23,45,120,1366,1035,2401
# 2016-03-23,23,March,2016,49,Adults (35-64),M,Australia,New South Wales,Accessories,Bike Racks,Hitch Rack - 4-Bike,20,45,120,1188,900,2088
# 2014-05-15,15,May,2014,47,Adults (35-64),F,Australia,New South Wales,Accessories,Bike Racks,Hitch Rack - 4-Bike,4,45,120,238,180,418
# 2016-05-15,15,May,2016,47,Adults (35-64),F,Australia,New South Wales,Accessories,Bike Racks,Hitch Rack - 4-Bike,5,45,120,297,225,522
# 2014-05-22,22,May,2014,47,Adults (35-64),F,Australia,Victoria,Accessories,Bike Racks,Hitch Rack - 4-Bike,4,45,120,199,180,379
# 2016-05-22,22,May,2016,47,Adults (35-64),F,Australia,Victoria,Accessories,Bike Racks,Hitch Rack - 4-Bike,2,45,120,100,90,190
# 2014-02-22,22,February,2014,35,Adults (35-64),M,Australia,Victoria,Accessories,Bike Racks,Hitch Rack - 4-Bike,22,45,120,1096,990,2086

# %% [markdown]
# ### **What exactly do we have? (Data View)**

# %%
sales = pd.read_csv('sample_data/sales_data.csv', parse_dates=['Date'])
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %% [markdown]
# ### **Table Count (Rows & Columns)**

# %%
sales.shape
# Out:
# (113036, 18)

# %% [markdown]
# ### **Meta Data**

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
#  16  Cost              113036 non-null  int64
#  17  Revenue           113036 non-null  int64
# dtypes: datetime64[ns](1), int64(9), object(8)
# memory usage: 15.5+ MB

# %% [markdown]
# ### **Data Description**

# %%
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# 50%        35.000000       10.000000       9.000000      24.000000
# 75%        43.000000       20.000000      42.000000      70.000000
# max        87.000000       32.000000    2171.000000    3578.000000
# std        11.021936        9.561857     549.835483     922.071219
#
#               Profit           Cost        Revenue
# count  113036.000000  113036.000000  113036.000000
# mean      285.051665     469.318695     754.370360
# min       -30.000000       1.000000       2.000000
# 25%        29.000000      28.000000      63.000000
# 50%       101.000000     108.000000     223.000000
# 75%       358.000000     432.000000     800.000000
# max     15096.000000   42978.000000   58074.000000
# std       453.887443     884.866118    1309.094674

# %% [markdown]
# ### **An Attribute | Column description**

# %%
sales['Unit_Cost'].describe()
# Out:
# count    113036.000000
# mean        267.296366
# std         549.835483
# min           1.000000
# 25%           2.000000
# 50%           9.000000
# 75%          42.000000
# max        2171.000000
# Name: Unit_Cost, dtype: float64

# %% [markdown]
# ### **Average Unit Cost Calculation**

# %%
sales['Unit_Cost'].mean()
# Out:
# np.float64(267.296365759581)

# %% [markdown]
# ### **Median Unit Cost Calculation**

# %%
sales['Unit_Cost'].median()
# Out:
# 9.0

# %% [markdown]
# ### **Unit Cost Boxplot Visualization**

# %%
sales['Unit_Cost'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ### **Revenue Boxplot Visualization**

# %%
sales['Revenue'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ### **Unit Price Boxplot Visualization**

# %%
sales['Unit_Price'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ### **Unit Cost Density Plot**

# %%
sales['Unit_Cost'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### **Age Group Density Plot**

# %%
sales['Age_Group'].value_counts().plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### **Customer Gender Bar Chart**

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar', figsize=(10,2))
plt.title('Customer Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **Gender Distribution Density Plot**

# %%
gender_numeric = pd.get_dummies(sales['Customer_Gender'], prefix='Gender').astype(int)


plt.figure(figsize=(14,6))
for column in gender_numeric.columns:
    gender_numeric[column].plot(kind='density', label=column)
plt.title('Gender Distribution (Numerical Conversion)')
plt.legend()
plt.show()

# %% [markdown]
# ### **Data View**

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# 0  Hitch Rack - 4-Bike               8         45         120     590   360
# 1  Hitch Rack - 4-Bike               8         45         120     590   360
# 2  Hitch Rack - 4-Bike              23         45         120    1366  1035
# 3  Hitch Rack - 4-Bike              20         45         120    1188   900
# 4  Hitch Rack - 4-Bike               4         45         120     238   180
#
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %% [markdown]
# ### **Age Group Value Counts**

# %%
sales['Age_Group'].value_counts()
# Out:
# Age_Group
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: count, dtype: int64

# %% [markdown]
# ### **Age Group Pie Chart**

# %%
sales['Age_Group'].value_counts().plot(kind='pie', figsize=(5,5))
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **Age Group Bar Chart**

# %%
sales['Age_Group'].value_counts().plot(kind='bar', figsize=(8,3))
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### **Correlation Matrix Calculation**

# %%
corr = sales.select_dtypes(include=np.number).corr()

corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# Customer_Age     -0.020262  0.004319 -0.016013 -0.009326
# Order_Quantity   -0.515925 -0.238863 -0.340382 -0.312895
# Unit_Cost         0.997894  0.741020  0.829869  0.817865
# Unit_Price        1.000000  0.749870  0.826301  0.818522
# Profit            0.749870  1.000000  0.902233  0.956572
# Cost              0.826301  0.902233  1.000000  0.988758
# Revenue           0.818522  0.956572  0.988758  1.000000

# %% [markdown]
# ### **Correlation Matrix Heatmap**

# %%
plt.figure(figsize=(10,17))
plt.matshow(corr, cmap='RdBu')

plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
plt.colorbar()
plt.show()

# %% [markdown]
# ### **Customer Age vs Revenue Scatter Plot**

# %%
sales.plot(kind='scatter', x='Customer_Age', y='Revenue', figsize=(6,6))
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Revenue'>

# %% [markdown]
# ### **Revenue vs Profit Scatter Plot**

# %%
sales.plot(kind='scatter', x='Revenue', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Revenue', ylabel='Profit'>

# %% [markdown]
# ### **Profit by Age Group Boxplot**

# %%
ax = sales[['Profit', 'Age_Group']].boxplot(by='Age_Group', figsize=(10,6))
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### **Multiple Variables Boxplots**

# %%
boxplot_cols = ['Year', 'Customer_Age', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit']

sales[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(12,7))
# Out:
# Year                 Axes(0.125,0.53;0.227941x0.35)
# Customer_Age      Axes(0.398529,0.53;0.227941x0.35)
# Order_Quantity    Axes(0.672059,0.53;0.227941x0.35)
# Unit_Cost            Axes(0.125,0.11;0.227941x0.35)
# Unit_Price        Axes(0.398529,0.11;0.227941x0.35)
# Profit            Axes(0.672059,0.11;0.227941x0.35)
# dtype: object

# %% [markdown]
# # **Column wrangling**

# %% [markdown]
# We can also create new columns or modify existing ones.

# %% [markdown]
# ### **Revenue per Age Calculation**

# %%
sales['Revenue_per_Age'] = sales['Revenue'] / sales['Customer_Age']
sales['Revenue_per_Age'].head()
# Out:
# 0    50.000000
# 1    50.000000
# 2    49.000000
# 3    42.612245
# 4     8.893617
# Name: Revenue_per_Age, dtype: float64

# %% [markdown]
# ### **Revenue per Age Density Plot**

# %%
sales['Revenue_per_Age'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### **Revenue per Age Histogram**

# %%
sales['Revenue_per_Age'].plot(kind='hist', figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### **Calculated Cost Column Creation**

# %%
sales['Calculated_Cost'] = sales['Order_Quantity'] * sales['Unit_Cost']

sales['Calculated_Cost'].head()
# Out:
# 0     360
# 1     360
# 2    1035
# 3     900
# 4     180
# Name: Calculated_Cost, dtype: int64

# %% [markdown]
# ### **Calculated vs Actual Cost Mismatch Count**

# %%
(sales['Calculated_Cost'] != sales['Cost']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Calculated Cost vs Profit Scatter Plot**

# %%
sales.plot(kind='scatter', x='Calculated_Cost', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Calculated_Cost', ylabel='Profit'>

# %% [markdown]
# ### **Calculated Revenue Column Creation**

# %%
sales['Calculated_Revenue'] = sales['Cost'] + sales['Profit']
sales['Calculated_Revenue'].head()
# Out:
# 0     950
# 1     950
# 2    2401
# 3    2088
# 4     418
# Name: Calculated_Revenue, dtype: int64

# %% [markdown]
# ### **Calculated Revenue Column Creation**

# %%
(sales['Calculated_Revenue'] != sales['Revenue']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Revenue Histogram**

# %%
sales['Revenue'].plot(kind='hist', bins=100, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Modify all Unit_Price values adding 3% tax to them

# %% [markdown]
# ### **Unit Price Head**

# %%
sales['Unit_Price'].head()
# Out:
# 0    120
# 1    120
# 2    120
# 3    120
# 4    120
# Name: Unit_Price, dtype: int64

# %% [markdown]
# ### **Unit Price Adjustment by 3%**

# %%
sales['Unit_Price'] *= 1.03
sales['Unit_Price'].head()
# Out:
# 0    131.12724
# 1    131.12724
# 2    131.12724
# 3    131.12724
# 4    131.12724
# Name: Unit_Price, dtype: float64

# %% [markdown]
# # Selection & Indexing

# %% [markdown]
# ### **Filter Sales by Kentucky State**

# %%
sales.loc[sales['State'] == 'Kentucky']
# Out:
#             Date  Day     Month  Year  Customer_Age       Age_Group  \
# 156   2013-11-04    4  November  2013            40  Adults (35-64)
# 157   2015-11-04    4  November  2015            40  Adults (35-64)
# 23826 2014-04-16   16     April  2014            40  Adults (35-64)
# 23827 2016-04-16   16     April  2016            40  Adults (35-64)
# 31446 2014-04-16   16     April  2014            40  Adults (35-64)
# 31447 2016-04-16   16     April  2016            40  Adults (35-64)
# 79670 2014-04-16   16     April  2014            40  Adults (35-64)
# 79671 2014-04-16   16     April  2014            40  Adults (35-64)
# 79672 2016-04-16   16     April  2016            40  Adults (35-64)
# 79673 2016-04-16   16     April  2016            40  Adults (35-64)
#
#       Customer_Gender        Country     State Product_Category  ...  \
# 156                 M  United States  Kentucky      Accessories  ...
# 157                 M  United States  Kentucky      Accessories  ...
# 23826               M  United States  Kentucky      Accessories  ...
# 23827               M  United States  Kentucky      Accessories  ...
# 31446               M  United States  Kentucky      Accessories  ...
# 31447               M  United States  Kentucky      Accessories  ...
# 79670               M  United States  Kentucky      Accessories  ...
# 79671               M  United States  Kentucky      Accessories  ...
# 79672               M  United States  Kentucky      Accessories  ...
# 79673               M  United States  Kentucky      Accessories  ...
#
#       Order_Quantity Unit_Cost  Unit_Price  Profit  Cost  Revenue  \
# 156                1        45  131.127240      63    45      108
# 157                1        45  131.127240      63    45      108
# 23826             12         8   24.039994     142    96      238
# 23827             14         8   24.039994     165   112      277
# 31446             29        13   38.245445     537   377      914
# 31447             31        13   38.245445     574   403      977
# 79670              2        11   32.781810      32    22       54
# 79671             21        11   32.781810     336   231      567
# 79672              1        11   32.781810      16    11       27
# 79673             18        11   32.781810     288   198      486
#
#        Revenue_per_Age  Calculated_Cost  Calculted_Revenue  Calculated_Revenue
# 156              2.700               45                108                 108
# 157              2.700               45                108                 108
# 23826            5.950               96                238                 238
# 23827            6.925              112                277                 277
# 31446           22.850              377                914                 914
# 31447           24.425              403                977                 977
# 79670            1.350               22                 54                  54
# 79671           14.175              231                567                 567
# 79672            0.675               11                 27                  27
# 79673           12.150              198                486                 486
#
# [10 rows x 22 columns]

# %% [markdown]
# ### **Average Revenue for Adult Age Group**

# %%
sales.loc[sales['Age_Group'] == 'Adults (35-64)', 'Revenue'].mean()
# Out:
# np.float64(762.8287654055604)

# %% [markdown]
# ### **Youth and Adults Row Count**

# %%
sales.loc[(sales['Age_Group'] == 'Youth (<25)') | (sales['Age_Group'] == 'Adults (35-64)')].shape[0]
# Out:
# 73652

# %% [markdown]
# ### **Average Revenue of US Adults**

# %%
sales.loc[(sales['Age_Group'] == 'Adults (35-64)') & (sales['Country'] == 'United States'), 'Revenue'].mean()
# Out:
# np.float64(726.7260473588342)

# %% [markdown]
# ### **France Revenue Head**

# %%
sales.loc[sales['Country'] == 'France', 'Revenue'].head()
# Out:
# 50     787
# 51     787
# 52    2957
# 53    2851
# 60     626
# Name: Revenue, dtype: int64

# %% [markdown]
# ### **France Revenue Adjustment by 10%**

# %%
sales['Revenue'] = sales['Revenue'].astype(float)
sales.loc[sales['Country'] == 'France', 'Revenue'] *= 1.1
sales.loc[sales['Country'] == 'France', 'Revenue'].head()
# Out:
# 50    1152.2467
# 51    1152.2467
# 52    4329.3437
# 53    4174.1491
# 60     916.5266
# Name: Revenue, dtype: float64
